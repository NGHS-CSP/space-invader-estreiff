# %% [markdown]
# # Space Invader Challenge
#
# Your quest is multi-part.
# 1. First run the cell below and acquaint yourself with Bob the friendly space invader.
# 2. In the 3rd code chunk down in the cell below there is a comment that says 'INSERT CODE HERE TO TURN WHITE INTO MAGENTA'... <b>do that</b>
# 3. In the cell below that change the <b>black </b>in the image to <b>green</b>. Comment your code with a Markdown Cell before the code.
# 3. In the cell below hack it. Do something creative with the code (Suggestions - Turn the top half of the white to one color and the bottom half to another color. Digitally edit another image a similar way. What ever you do comment your code with a Markdown Cell before the code.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import os.path
import numpy as np      # “as” lets us use standard abbreviations

'''Read the image data'''
directory = os.getcwd()
filename = os.path.join(directory, 'space-invaders-white.jpg')
# Read the image data into an array
img = plt.imread(filename)
img.setflags(write=1)

height = len(img)
width = len(img[0])
for r in range(height):
    for c in range(width):
        if img[r][c][0] >200 and img[r][c][1]>200 and img[r][c][2]>200:
            img[r][c] = img[r][c]
            


fig, ax = plt.subplots(1, 1)
# Show the image data in a subplot
ax.imshow(img, interpolation='none')
# Show the figure on the screen
fig.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import os.path
import numpy as np      # “as” lets us use standard abbreviations

'''Read the image data'''
directory = os.getcwd()
filename = os.path.join(directory, 'space-invaders-white.jpg')
# Read the image data into an array
img = plt.imread(filename)
img.setflags(write=1)

height = len(img)
width = len(img[0])
for r in range(height):
    for c in range(width):
        if img[r][c][0] >200 and img[r][c][1]>200 and img[r][c][2]>200:
            img[r][c] = [250,0,150]
            


fig, ax = plt.subplots(1, 1)
# Show the image data in a subplot
ax.imshow(img, interpolation='none')
# Show the figure on the screen
fig.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import os.path
import numpy as np      # “as” lets us use standard abbreviations

'''Read the image data'''
directory = os.getcwd()
filename = os.path.join(directory, 'space-invaders-white.jpg')
# Read the image data into an array
img = plt.imread(filename)
img.setflags(write=1)

height = len(img)
width = len(img[0])
for r in range(height):
    for c in range(width):
        #changing it to change the black of the picture to green instead of the white
        if img[r][c][0] <200 and img[r][c][1]<200 and img[r][c][2]<200:
            img[r][c] = [0,120,80]
            


fig, ax = plt.subplots(1, 1)
# Show the image data in a subplot
ax.imshow(img, interpolation='none')
# Show the figure on the screen
fig.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import os.path
import numpy as np      # “as” lets us use standard abbreviations

'''Read the image data'''
directory = os.getcwd()
filename = os.path.join(directory, 'space-invaders-white.jpg')
# Read the image data into an array
img = plt.imread(filename)
img.setflags(write=1)

height = len(img)
width = len(img[0])
for r in range(height):
    for c in range(width):
        if img[r][c][0] <200 and img[r][c][1]<200 and img[r][c][2]<200:
            if r% 3 == 0 or c% 3 == 0:
                    img[r][c] = [175,90,150]
            if r% 2 ==0 and c%2 == 0:
                img[r][c] = [30,90,120]
            if r%2!=0 and c%2!=0:
                img[r][c]=[200,255,200]
        if img[r][c][0] >200 and img[r][c][1]>200 and img[r][c][2]>200:
            if r% 3 == 0 or c% 3 == 0:
                    img[r][c] = [10,90,20]
            if r% 2 ==0 and c%2 == 0:
                img[r][c] = [50,50,50]
            if r%2!=0 and c%2!=0:
                img[r][c]=[90,20,10]
            


fig, ax = plt.subplots(1, 1)
# Show the image data in a subplot
ax.imshow(img, interpolation='none')
# Show the figure on the screen
fig.show()
#my interesting pattern

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import os.path
import numpy as np      # “as” lets us use standard abbreviations

'''Read the image data'''
directory = os.getcwd()
filename = os.path.join(directory, 'space-invaders-white.jpg')
# Read the image data into an array
img = plt.imread(filename)
img.setflags(write=1)

height = len(img)
width = len(img[0])
for r in range(height):
    for c in range(width):
        if img[r][c][0] <200 and img[r][c][1]<200 and img[r][c][2]<200:
            if r% 2 ==0 or r%3 ==0 and c%2==2:
                img[r][c] = [30,90,120]
            if r%2!=0 and r%3!=0 and c%2!=2:
                img[r][c]=[200,255,200]
        if img[r][c][0] >200 and img[r][c][1]>200 and img[r][c][2]>200:
            if r%2==0: 
                if c%2==0:
                    img[r%2][c%2] = [255,0,0]
                if c%2 != 0:
                    img[r][c] = [150,0,150]
            else:
                img[r][c] = [10,10,10]
                
            


fig, ax = plt.subplots(1, 1)
# Show the image data in a subplot
ax.imshow(img, interpolation='none')
# Show the figure on the screen
fig.show()
#the recommended checkerboard approach
